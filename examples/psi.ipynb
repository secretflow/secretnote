# %% [markdown]
# ## 前期准备
#
# alice 和 bob 节点分别启动 ray 集群。
#
# ```
# ray start --head --node-ip-address="ip" --port="port" --include-dashboard=False --disable-usage-stats
# ```
#
# 屏幕输出中显示 <span style="color: #008A00">Ray runtime started</span>，则说明 Ray 的主节点启动成功。

# %% [markdown]
# ## 初始化 SecretFlow
#
# alice 和 bob 节点都需要初始化 secretflow，初始化语句只有在 self_party 上有区别。
#
# 1. 分别使用 Ray 主节点的 node-ip-address 和 port 填充 sf.init 的 address 参数。
# 2. parties 中 alice 和 bob 的 address 分别填可以被对方访问的地址，并且选择一个**未被占用的端口。**

# %%
import secretflow as sf
import spu

network_conf = {
    'parties': {
        'alice': {
            'address': 'alice:8080',
        },
        'bob': {
            'address': 'bob:8080',
        },
    },
}

# %% [markdown]
# ### alice 和 bob 初始化
#
# <span style="color: #BA4081">注意：下面初始化语句是分别只在对应的 alice 或 bob 节点执行的。除了初始化语句，后面所有代码，会被同时下发到 alice 和 bob 节点执行。</span>

# %%
sf.shutdown()
sf.init(
    address='127.0.0.1:6379',
    cluster_config={**network_conf, 'self_party': 'alice'},
    log_to_driver=True,
)
# Out:
# <h4>Alice (You)'s Output:</h4>
# 2023-10-10 05:18:22,228	INFO worker.py:1352 -- Connecting to existing Ray cluster at address: 172.21.0.2:6379...
# 2023-10-10 05:18:22,253	INFO worker.py:1529 -- Connected to Ray cluster. View the dashboard at http://172.21.0.2:8265
# 2023-10-10 05:18:22 INFO api.py:147 [alice] --  Started rayfed with {'CLUSTER_ADDRESSES': {'alice': 'alice:8080', 'bob': 'bob:8080'}, 'CURRENT_PARTY_NAME': 'alice', 'TLS_CONFIG': {}}
# 2023-10-10 05:18:22 INFO cleanup.py:58 [alice] --  Start check sending thread.
# 2023-10-10 05:18:22 INFO cleanup.py:67 [alice] --  Start check sending monitor thread.
# 2023-10-10 05:18:23 INFO barriers.py:235 [alice] --  Succeeded to create receiver proxy actor.
# (ReceiverProxyActor pid=626) 2023-10-10 05:18:23 INFO grpc_proxy.py:306 [alice] --  ReceiveProxy binding port 8080, options: (('grpc.enable_retries', 1), ('grpc.so_reuseport', 0), ('grpc.max_send_message_length', 524288000), ('grpc.max_receive_message_length', 524288000), ('grpc.service_config', '{"methodConfig": [{"name": [{"service": "GrpcService"}], "retryPolicy": {"maxAttempts": 5, "initialBackoff": "5s", "maxBackoff": "30s", "backoffMultiplier": 2, "retryableStatusCodes": ["UNAVAILABLE"]}}]}'))...
# (ReceiverProxyActor pid=626) 2023-10-10 05:18:23 INFO grpc_proxy.py:326 [alice] --  Successfully start Grpc service without credentials.
# 2023-10-10 05:18:24 INFO barriers.py:283 [alice] --  SenderProxyActor has successfully created.
# 2023-10-10 05:18:24 INFO barriers.py:438 [alice] --  Try ping ['bob'] at 0 attemp, up to 3600 attemps.

# %%
sf.shutdown()
sf.init(
    address='127.0.0.1:6379',
    cluster_config={**network_conf, 'self_party': 'bob'},
    log_to_driver=True,
)
# Out:
# <h4>Bob's Output:</h4>
# 2023-10-10 05:18:22,223	INFO worker.py:1352 -- Connecting to existing Ray cluster at address: 172.21.0.3:6379...
# 2023-10-10 05:18:22,249	INFO worker.py:1529 -- Connected to Ray cluster. View the dashboard at http://172.21.0.3:8265
# 2023-10-10 05:18:22 INFO api.py:147 [bob] --  Started rayfed with {'CLUSTER_ADDRESSES': {'alice': 'alice:8080', 'bob': 'bob:8080'}, 'CURRENT_PARTY_NAME': 'bob', 'TLS_CONFIG': {}}
# 2023-10-10 05:18:22 INFO cleanup.py:58 [bob] --  Start check sending thread.
# 2023-10-10 05:18:22 INFO cleanup.py:67 [bob] --  Start check sending monitor thread.
# 2023-10-10 05:18:23 INFO barriers.py:235 [bob] --  Succeeded to create receiver proxy actor.
# (ReceiverProxyActor pid=598) 2023-10-10 05:18:23 INFO grpc_proxy.py:306 [bob] --  ReceiveProxy binding port 8080, options: (('grpc.enable_retries', 1), ('grpc.so_reuseport', 0), ('grpc.max_send_message_length', 524288000), ('grpc.max_receive_message_length', 524288000), ('grpc.service_config', '{"methodConfig": [{"name": [{"service": "GrpcService"}], "retryPolicy": {"maxAttempts": 5, "initialBackoff": "5s", "maxBackoff": "30s", "backoffMultiplier": 2, "retryableStatusCodes": ["UNAVAILABLE"]}}]}'))...
# (ReceiverProxyActor pid=598) 2023-10-10 05:18:23 INFO grpc_proxy.py:326 [bob] --  Successfully start Grpc service without credentials.
# 2023-10-10 05:18:24 INFO barriers.py:283 [bob] --  SenderProxyActor has successfully created.
# 2023-10-10 05:18:24 INFO barriers.py:438 [bob] --  Try ping ['alice'] at 0 attemp, up to 3600 attemps.

# %% [markdown]
# ## 初始化 SPU
#
# 1. alice 的 address 请填写可以被 bob 访通的地址，并且选择一个**未被占用的端口** ，注意不要和 Ray 端口冲突。
# 2. alice 的 listen_addr 可以和 alice address 里的端口一样。
# 3. bob 的 address 请填写可以被 alice 访通的地址，并且选择一个**未被占用的端口** ，注意不要和 Ray 端口冲突。
# 4. bob 的 listen_addr 可以和 bob address 里的端口一样。

# %%
alice, bob = sf.PYU('alice'), sf.PYU('bob')
spu_conf = {
    "nodes": [
        {
            "party": "alice",
            "address": "alice:8081",
            "listen_addr": "alice:8081"
        },
        {
            "party": "bob",
            "address": "bob:8081",
            "listen_addr": "alice:8081"
        },
    ],
    "runtime_config": {
        "protocol": spu.spu_pb2.SEMI2K,
        "field": spu.spu_pb2.FM128,
        "sigmoid_mode": spu.spu_pb2.RuntimeConfig.SIGMOID_REAL,
    },
}
spu = sf.SPU(cluster_def=spu_conf)

# %% [markdown]
# ## 隐私求交
#
# <span style="color: rgb(50, 50, 50)">提供 </span>`psi_csv`<span style="color: rgb(50, 50, 50)"> 函数， </span>`psi_csv`<span style="color: rgb(50, 50, 50)"> 将 csv 文件作为输入，并在求交后生成 csv 文件。默认协议为 </span>[**KKRT**](https://eprint.iacr.org/2016/799.pdf)<span style="color: rgb(50, 50, 50)">。</span>

# %%
import os

current_dir = os.getcwd()

input_path = {alice: f'{current_dir}/iris_alice.csv', bob: f'{current_dir}/iris_bob.csv'}
output_path = {alice: f'{current_dir}/iris_alice_psi.csv', bob: f'{current_dir}/iris_alice_psi.csv'}
spu.psi_csv('uid', input_path, output_path, 'alice')
# Out:
# <h4>Alice (You)'s Output:</h4>
# 2023-10-10 05:18:26,135	WARNING worker.py:1851 -- Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 823, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 875, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 830, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 834, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 780, in ray._raylet.execute_task.function_executor
#   File "/usr/local/lib/python3.8/site-packages/ray/_private/function_manager.py", line 674, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "/usr/local/lib/python3.8/site-packages/secretflow/device/device/spu.py", line 370, in __init__
#     self.link = spu_link.create_brpc(desc, rank)
# RuntimeError: what:
# 	[external/yacl/yacl/link/transport/brpc_link.cc:130] brpc server failed start
# Stacktrace:
# #0 yacl::link::FactoryBrpc::CreateContext()+0x7f5013ac5799
# #1 pybind11::cpp_function::initialize<>()::{lambda()#3}::_FUN()+0x7f50125ecad6
# #2 pybind11::cpp_function::dispatcher()+0x7f50125cf1c6
# #3 PyCFunction_Call+0x4e0212
#
# stacktrace:
# #0 yacl::link::FactoryBrpc::CreateContext()+0x7f5013ac5799
# #1 pybind11::cpp_function::initialize<>()::{lambda()#3}::_FUN()+0x7f50125ecad6
# #2 pybind11::cpp_function::dispatcher()+0x7f50125cf1c6
# #3 PyCFunction_Call+0x4e0212
#
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 1135, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 1045, in ray._raylet.execute_task_with_cancellation_handler
#   File "python/ray/_raylet.pyx", line 782, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 945, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 575, in ray._raylet.store_task_errors
#   File "/usr/local/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "/usr/local/lib/python3.8/site-packages/secretflow/device/device/spu.py", line 379, in __repr__
#     return f"SPURuntime(device_id={self.id}, party={self.party})"
# AttributeError: 'SPURuntime' object has no attribute 'id'
# An unexpected internal error occurred while the worker was executing a task.
# 2023-10-10 05:18:26,139	WARNING worker.py:1851 -- A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: ffffffffffffffff7b0a71680fdf55c835e15cbd02000000 Worker ID: 3e983cafece5f7ed736ea470a212e17301aa91a14273cf74277260cf Node ID: 83e3e86722f8dcfa88fcfa76345fdac10f8d431899b37b4e1ca6c4ce Worker IP address: 172.21.0.2 Worker port: 10009 Worker PID: 716 Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code None.
#  Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 823, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 875, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 830, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 834, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 780, in ray._raylet.execute_task.function_executor
#   File "/usr/local/lib/python3.8/site-packages/ray/_private/function_manager.py", line 674, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "/usr/local/lib/python3.8/site-packages/secretflow/device/device/spu.py", line 370, in __init__
#     self.link = spu_link.create_brpc(desc, rank)
# RuntimeError: what:
# 	[external/yacl/yacl/link/transport/brpc_link.cc:130] brpc server failed start
# Stacktrace:
# #0 yacl::link::FactoryBrpc::CreateContext()+0x7f5013ac5799
# #1 pybind11::cpp_function::initialize<>()::{lambda()#3}::_FUN()+0x7f50125ecad6
# #2 pybind11::cpp_function::dispatcher()+0x7f50125cf1c6
# #3 PyCFunction_Call+0x4e0212
#
# stacktrace:
# #0 yacl::link::FactoryBrpc::CreateContext()+0x7f5013ac5799
# #1 pybind11::cpp_function::initialize<>()::{lambda()#3}::_FUN()+0x7f50125ecad6
# #2 pybind11::cpp_function::dispatcher()+0x7f50125cf1c6
# #3 PyCFunction_Call+0x4e0212
#
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 1135, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 1045, in ray._raylet.execute_task_with_cancellation_handler
#   File "python/ray/_raylet.pyx", line 782, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 945, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 575, in ray._raylet.store_task_errors
#   File "/usr/local/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "/usr/local/lib/python3.8/site-packages/secretflow/device/device/spu.py", line 379, in __repr__
#     return f"SPURuntime(device_id={self.id}, party={self.party})"
# AttributeError: 'SPURuntime' object has no attribute 'id'
# An unexpected internal error occurred while the worker was executing a task.
# 2023-10-10 05:18:26 WARNING cleanup.py:99 [alice] --  Failed to send ObjectRef(0d12401e8fa9a714c8e08e9be09efa78b6a95cb50200000001000000) with error: ray::SenderProxyActor.send() (pid=671, ip=172.21.0.2, repr=<fed.proxy.barriers.SenderProxyActor object at 0x7f112c15a250>)
#   At least one of the input arguments for this task could not be computed:
# ray.exceptions.RayActorError: The actor died unexpectedly before finishing this task.
# 	class_name: SPURuntime
# 	actor_id: 7b0a71680fdf55c835e15cbd02000000
# 	pid: 716
# 	namespace: 36f67683-355f-43b8-8ac5-b0d3b29372ae
# 	ip: 172.21.0.2
# The actor is dead because its worker process has died. Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code None.
#  Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/secretflow/device/device/spu.py", line 370, in __init__
#     self.link = spu_link.create_brpc(desc, rank)
# RuntimeError: what:
# 	[external/yacl/yacl/link/transport/brpc_link.cc:130] brpc server failed start
# Stacktrace:
# #0 yacl::link::FactoryBrpc::CreateContext()+0x7f5013ac5799
# #1 pybind11::cpp_function::initialize<>()::{lambda()#3}::_FUN()+0x7f50125ecad6
# #2 pybind11::cpp_function::dispatcher()+0x7f50125cf1c6
# #3 PyCFunction_Call+0x4e0212
#
# stacktrace:
# #0 yacl::link::FactoryBrpc::CreateContext()+0x7f5013ac5799
# #1 pybind11::cpp_function::initialize<>()::{lambda()#3}::_FUN()+0x7f50125ecad6
# #2 pybind11::cpp_function::dispatcher()+0x7f50125cf1c6
# #3 PyCFunction_Call+0x4e0212
#
#
#
# During handling of the above exception, another exception occurred:
#
# ray::SenderProxyActor.send() (pid=671, ip=172.21.0.2, repr=<fed.proxy.barriers.SenderProxyActor object at 0x7f112c15a250>)
#   File "/usr/local/lib/python3.8/site-packages/secretflow/device/device/spu.py", line 379, in __repr__
#     return f"SPURuntime(device_id={self.id}, party={self.party})"
# AttributeError: 'SPURuntime' object has no attribute 'id'
# An unexpected internal error occurred while the worker was executing a task.
# 2023-10-10 05:18:26 WARNING cleanup.py:102 [alice] --  Signal self to exit.
# 2023-10-10 05:18:26 INFO cleanup.py:106 [alice] --  Check sending thread was exited.
# *** SIGTERM received at time=1696915106 on cpu 5 ***
# PC: @     0x7fd8f860e848  (unknown)  pthread_cond_timedwait@@GLIBC_2.3.2
#     @     0x7fd8f8612cf0  (unknown)  (unknown)
# [2023-10-10 05:18:26,158 E 541 541] logging.cc:361: *** SIGTERM received at time=1696915106 on cpu 5 ***
# [2023-10-10 05:18:26,158 E 541 541] logging.cc:361: PC: @     0x7fd8f860e848  (unknown)  pthread_cond_timedwait@@GLIBC_2.3.2
# [2023-10-10 05:18:26,158 E 541 541] logging.cc:361:     @     0x7fd8f8612cf0  (unknown)  (unknown)
# (SPURuntime pid=716) 2023-10-10 05:18:26,134	ERROR worker.py:763 -- Worker exits with an exit code None.
# (SPURuntime pid=716)  Traceback (most recent call last):
# (SPURuntime pid=716)   File "python/ray/_raylet.pyx", line 823, in ray._raylet.execute_task
# (SPURuntime pid=716)   File "python/ray/_raylet.pyx", line 875, in ray._raylet.execute_task
# (SPURuntime pid=716)   File "python/ray/_raylet.pyx", line 830, in ray._raylet.execute_task
# (SPURuntime pid=716)   File "python/ray/_raylet.pyx", line 834, in ray._raylet.execute_task
# (SPURuntime pid=716)   File "python/ray/_raylet.pyx", line 780, in ray._raylet.execute_task.function_executor
# (SPURuntime pid=716)   File "/usr/local/lib/python3.8/site-packages/ray/_private/function_manager.py", line 674, in actor_method_executor
# (SPURuntime pid=716)     return method(__ray_actor, *args, **kwargs)
# (SPURuntime pid=716)   File "/usr/local/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (SPURuntime pid=716)     return method(self, *_args, **_kwargs)
# (SPURuntime pid=716)   File "/usr/local/lib/python3.8/site-packages/secretflow/device/device/spu.py", line 370, in __init__
# (SPURuntime pid=716)     self.link = spu_link.create_brpc(desc, rank)
# (SPURuntime pid=716) RuntimeError: what:
# (SPURuntime pid=716) 	[external/yacl/yacl/link/transport/brpc_link.cc:130] brpc server failed start
# (SPURuntime pid=716) Stacktrace:
# (SPURuntime pid=716) #0 yacl::link::FactoryBrpc::CreateContext()+0x7f5013ac5799
# (SPURuntime pid=716) #1 pybind11::cpp_function::initialize<>()::{lambda()#3}::_FUN()+0x7f50125ecad6
# (SPURuntime pid=716) #2 pybind11::cpp_function::dispatcher()+0x7f50125cf1c6
# (SPURuntime pid=716) #3 PyCFunction_Call+0x4e0212
# (SPURuntime pid=716)
# (SPURuntime pid=716) stacktrace:
# (SPURuntime pid=716) #0 yacl::link::FactoryBrpc::CreateContext()+0x7f5013ac5799
# (SPURuntime pid=716) #1 pybind11::cpp_function::initialize<>()::{lambda()#3}::_FUN()+0x7f50125ecad6
# (SPURuntime pid=716) #2 pybind11::cpp_function::dispatcher()+0x7f50125cf1c6
# (SPURuntime pid=716) #3 PyCFunction_Call+0x4e0212
# (SPURuntime pid=716)
# (SPURuntime pid=716)
# (SPURuntime pid=716)
# (SPURuntime pid=716) During handling of the above exception, another exception occurred:
# (SPURuntime pid=716)
# (SPURuntime pid=716) Traceback (most recent call last):
# (SPURuntime pid=716)   File "python/ray/_raylet.pyx", line 1135, in ray._raylet.task_execution_handler
# (SPURuntime pid=716)   File "python/ray/_raylet.pyx", line 1045, in ray._raylet.execute_task_with_cancellation_handler
# (SPURuntime pid=716)   File "python/ray/_raylet.pyx", line 782, in ray._raylet.execute_task
# (SPURuntime pid=716)   File "python/ray/_raylet.pyx", line 945, in ray._raylet.execute_task
# (SPURuntime pid=716)   File "python/ray/_raylet.pyx", line 575, in ray._raylet.store_task_errors
# (SPURuntime pid=716)   File "/usr/local/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (SPURuntime pid=716)     return method(self, *_args, **_kwargs)
# (SPURuntime pid=716)   File "/usr/local/lib/python3.8/site-packages/secretflow/device/device/spu.py", line 379, in __repr__
# (SPURuntime pid=716)     return f"SPURuntime(device_id={self.id}, party={self.party})"
# (SPURuntime pid=716) AttributeError: 'SPURuntime' object has no attribute 'id'
# (SPURuntime pid=716) An unexpected internal error occurred while the worker was executing a task.
# (SPURuntime pid=716) Traceback (most recent call last):
# (SPURuntime pid=716)   File "python/ray/_raylet.pyx", line 823, in ray._raylet.execute_task
# (SPURuntime pid=716)   File "python/ray/_raylet.pyx", line 875, in ray._raylet.execute_task
# (SPURuntime pid=716)   File "python/ray/_raylet.pyx", line 830, in ray._raylet.execute_task
# (SPURuntime pid=716)   File "python/ray/_raylet.pyx", line 834, in ray._raylet.execute_task
# (SPURuntime pid=716)   File "python/ray/_raylet.pyx", line 780, in ray._raylet.execute_task.function_executor
# (SPURuntime pid=716)   File "/usr/local/lib/python3.8/site-packages/ray/_private/function_manager.py", line 674, in actor_method_executor
# (SPURuntime pid=716)     return method(__ray_actor, *args, **kwargs)
# (SPURuntime pid=716)   File "/usr/local/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (SPURuntime pid=716)     return method(self, *_args, **_kwargs)
# (SPURuntime pid=716)   File "/usr/local/lib/python3.8/site-packages/secretflow/device/device/spu.py", line 370, in __init__
# (SPURuntime pid=716)     self.link = spu_link.create_brpc(desc, rank)
# (SPURuntime pid=716) RuntimeError: what:
# (SPURuntime pid=716) 	[external/yacl/yacl/link/transport/brpc_link.cc:130] brpc server failed start
# (SPURuntime pid=716) Stacktrace:
# (SPURuntime pid=716) #0 yacl::link::FactoryBrpc::CreateContext()+0x7f5013ac5799
# (SPURuntime pid=716) #1 pybind11::cpp_function::initialize<>()::{lambda()#3}::_FUN()+0x7f50125ecad6
# (SPURuntime pid=716) #2 pybind11::cpp_function::dispatcher()+0x7f50125cf1c6
# (SPURuntime pid=716) #3 PyCFunction_Call+0x4e0212
# (SPURuntime pid=716)
# (SPURuntime pid=716) stacktrace:
# (SPURuntime pid=716) #0 yacl::link::FactoryBrpc::CreateContext()+0x7f5013ac5799
# (SPURuntime pid=716) #1 pybind11::cpp_function::initialize<>()::{lambda()#3}::_FUN()+0x7f50125ecad6
# (SPURuntime pid=716) #2 pybind11::cpp_function::dispatcher()+0x7f50125cf1c6
# (SPURuntime pid=716) #3 PyCFunction_Call+0x4e0212
# (SPURuntime pid=716)
# (SPURuntime pid=716)
# (SPURuntime pid=716)
# (SPURuntime pid=716) During handling of the above exception, another exception occurred:
# (SPURuntime pid=716)
# (SPURuntime pid=716) Traceback (most recent call last):
# (SPURuntime pid=716)   File "python/ray/_raylet.pyx", line 1135, in ray._raylet.task_execution_handler
# (SPURuntime pid=716)   File "python/ray/_raylet.pyx", line 1045, in ray._raylet.execute_task_with_cancellation_handler
# (SPURuntime pid=716)   File "python/ray/_raylet.pyx", line 782, in ray._raylet.execute_task
# (SPURuntime pid=716)   File "python/ray/_raylet.pyx", line 945, in ray._raylet.execute_task
# (SPURuntime pid=716)   File "python/ray/_raylet.pyx", line 575, in ray._raylet.store_task_errors
# (SPURuntime pid=716)   File "/usr/local/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (SPURuntime pid=716)     return method(self, *_args, **_kwargs)
# (SPURuntime pid=716)   File "/usr/local/lib/python3.8/site-packages/secretflow/device/device/spu.py", line 379, in __repr__
# (SPURuntime pid=716)     return f"SPURuntime(device_id={self.id}, party={self.party})"
# (SPURuntime pid=716) AttributeError: 'SPURuntime' object has no attribute 'id'
# (SPURuntime pid=716)
# (SPURuntime pid=716) During handling of the above exception, another exception occurred:
# (SPURuntime pid=716)
# (SPURuntime pid=716) Traceback (most recent call last):
# (SPURuntime pid=716)   File "python/ray/_raylet.pyx", line 1176, in ray._raylet.task_execution_handler
# (SPURuntime pid=716) SystemExit
# (SPURuntime pid=716) 2023-10-10 05:18:26.119 [error] [server.cpp:BRPC:1023] Fail to listen 172.21.0.3:8081
# (SPURuntime pid=716) 2023-10-10 05:18:26.132 [warning] [channel.h:~Channel:151] Channel destructor is called before WaitLinkTaskFinish, try stop send thread
# ---------------------------------------------------------------------------
# RayActorError                             Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[4], line 7
#       6 output_path = {alice: f'{current_dir}/iris_alice_psi.csv', bob: f'{current_dir}/iris_alice_psi.csv'}
# ----> 7 spu.psi_csv('uid', input_path, output_path, 'alice')
#
# File /usr/local/lib/python3.8/site-packages/secretflow/device/device/spu.py:1978, in SPU.psi_csv(self, key, input_path, output_path, receiver, protocol, precheck_input, sort, broadcast_result, bucket_size, curve_type, preprocess_path, ecdh_secret_key_path, dppsi_bob_sub_sampling, dppsi_epsilon, progress_callbacks, callbacks_interval_ms)
#    1948 """Private set intersection with csv file.
#    1949
#    1950 Args:
#    (...)
#    1975     List[Dict]: PSI reports output by SPU with order reserved.
#    1976 """
# -> 1978 return dispatch(
#    1979     'psi_csv',
#    1980     self,
#    1981     key,
#    1982     input_path,
#    1983     output_path,
#    1984     receiver,
#    1985     protocol,
#    1986     precheck_input,
#    1987     sort,
#    1988     broadcast_result,
#    1989     bucket_size,
#    1990     curve_type,
#    1991     preprocess_path,
#    1992     ecdh_secret_key_path,
#    1993     dppsi_bob_sub_sampling,
#    1994     dppsi_epsilon,
#    1995     progress_callbacks,
#    1996     callbacks_interval_ms,
#    1997 )
#
# File /usr/local/lib/python3.8/site-packages/secretflow/device/device/register.py:111, in dispatch(name, self, *args, **kwargs)
#     102 """Dispatch device kernel.
#     103
#     104 Args:
#    (...)
#     109     Kernel execution result.
#     110 """
# --> 111 return _registrar.dispatch(self.device_type, name, self, *args, **kwargs)
#
# File /usr/local/lib/python3.8/site-packages/secretflow/device/device/register.py:80, in Registrar.dispatch(self, device_type, name, *args, **kwargs)
#      79     raise KeyError(f'device: {device_type}, op: {name} not registered')
# ---> 80 return self._ops[device_type][name](*args, **kwargs)
#
# File /usr/local/lib/python3.8/site-packages/secretflow/device/kernels/spu.py:318, in psi_csv(device, key, input_path, output_path, receiver, protocol, precheck_input, sort, broadcast_result, bucket_size, curve_type, preprocess_path, ecdh_secret_key_path, dppsi_bob_sub_sampling, dppsi_epsilon, progress_callbacks, callbacks_interval_ms)
#     317 # wait for all tasks done
# --> 318 return sfd.get(res)
#
# File /usr/local/lib/python3.8/site-packages/secretflow/distributed/primitive.py:73, in get(object_refs)
#      72 if production_mode():
# ---> 73     return fed.get(object_refs)
#      74 else:
#
# File /usr/local/lib/python3.8/site-packages/fed/api.py:395, in get(fed_objects)
#     393         ray_refs.append(received_ray_object_ref)
# --> 395 values = ray.get(ray_refs)
#     396 if is_individual_id:
#
# File /usr/local/lib/python3.8/site-packages/ray/_private/client_mode_hook.py:105, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     104         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 105 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.8/site-packages/ray/_private/worker.py:2311, in get(object_refs, timeout)
#    2310         else:
# -> 2311             raise value
#    2313 if is_individual_id:
#
# RayActorError: The actor died unexpectedly before finishing this task.
# 	class_name: SPURuntime
# 	actor_id: 7b0a71680fdf55c835e15cbd02000000
# 	pid: 716
# 	namespace: 36f67683-355f-43b8-8ac5-b0d3b29372ae
# 	ip: 172.21.0.2
# The actor is dead because its worker process has died. Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code None.
#  Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 823, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 875, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 830, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 834, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 780, in ray._raylet.execute_task.function_executor
#   File "/usr/local/lib/python3.8/site-packages/ray/_private/function_manager.py", line 674, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "/usr/local/lib/python3.8/site-packages/secretflow/device/device/spu.py", line 370, in __init__
#     self.link = spu_link.create_brpc(desc, rank)
# RuntimeError: what:
# 	[external/yacl/yacl/link/transport/brpc_link.cc:130] brpc server failed start
# Stacktrace:
# #0 yacl::link::FactoryBrpc::CreateContext()+0x7f5013ac5799
# #1 pybind11::cpp_function::initialize<>()::{lambda()#3}::_FUN()+0x7f50125ecad6
# #2 pybind11::cpp_function::dispatcher()+0x7f50125cf1c6
# #3 PyCFunction_Call+0x4e0212
#
# stacktrace:
# #0 yacl::link::FactoryBrpc::CreateContext()+0x7f5013ac5799
# #1 pybind11::cpp_function::initialize<>()::{lambda()#3}::_FUN()+0x7f50125ecad6
# #2 pybind11::cpp_function::dispatcher()+0x7f50125cf1c6
# #3 PyCFunction_Call+0x4e0212
#
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 1135, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 1045, in ray._raylet.execute_task_with_cancellation_handler
#   File "python/ray/_raylet.pyx", line 782, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 945, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 575, in ray._raylet.store_task_errors
#   File "/usr/local/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "/usr/local/lib/python3.8/site-packages/secretflow/device/device/spu.py", line 379, in __repr__
#     return f"SPURuntime(device_id={self.id}, party={self.party})"
# AttributeError: 'SPURuntime' object has no attribute 'id'
# An unexpected internal error occurred while the worker was executing a task.
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File /usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:2105, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2103         stb = value._render_traceback_()
#    2104     else:
# -> 2105         stb = self.InteractiveTB.structured_traceback(
#    2106             etype, value, tb, tb_offset=tb_offset
#    2107         )
#    2109 except Exception:
#    2110     print(
#    2111         "Unexpected exception formatting exception. Falling back to standard exception"
#    2112     )
#
# File /usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py:1396, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1394 else:
#    1395     self.tb = etb
# -> 1396 return FormattedTB.structured_traceback(
#    1397     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1398 )
#
# File /usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py:1287, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1284 mode = self.mode
#    1285 if mode in self.verbose_modes:
#    1286     # Verbose modes need a full traceback
# -> 1287     return VerboseTB.structured_traceback(
#    1288         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1289     )
#    1290 elif mode == 'Minimal':
#    1291     return ListTB.get_exception_only(self, etype, value)
#
# File /usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py:1140, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1131 def structured_traceback(
#    1132     self,
#    1133     etype: type,
#    (...)
#    1137     number_of_lines_of_context: int = 5,
#    1138 ):
#    1139     """Return a nice text document describing the traceback."""
# -> 1140     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1141                                                            tb_offset)
#    1143     colors = self.Colors  # just a shorthand + quicker name lookup
#    1144     colorsnormal = colors.Normal  # used a lot
#
# File /usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py:1030, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1027 assert isinstance(tb_offset, int)
#    1028 head = self.prepare_header(str(etype), self.long_header)
#    1029 records = (
# -> 1030     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1031 )
#    1033 frames = []
#    1034 skipped = 0
#
# File /usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py:1098, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1096 while cf is not None:
#    1097     try:
# -> 1098         mod = inspect.getmodule(cf.tb_frame)
#    1099         if mod is not None:
#    1100             mod_name = mod.__name__
#
# File /usr/local/lib/python3.8/inspect.py:754, in getmodule(object, _filename)
#     751         f = getabsfile(module)
#     752         # Always map to the name the module knows itself by
#     753         modulesbyfile[f] = modulesbyfile[
# --> 754             os.path.realpath(f)] = module.__name__
#     755 if file in modulesbyfile:
#     756     return sys.modules.get(modulesbyfile[file])
#
# File /usr/local/lib/python3.8/posixpath.py:391, in realpath(filename)
#     388     """Return the canonical path of the specified filename, eliminating any
#     389 symbolic links encountered in the path."""
#     390     filename = os.fspath(filename)
# --> 391     path, ok = _joinrealpath(filename[:0], filename, {})
#     392     return abspath(path)
#
# File /usr/local/lib/python3.8/posixpath.py:425, in _joinrealpath(path, rest, seen)
#     423     continue
#     424 newpath = join(path, name)
# --> 425 if not islink(newpath):
#     426     path = newpath
#     427     continue
#
# File /usr/local/lib/python3.8/posixpath.py:167, in islink(path)
#     165 """Test whether a path is a symbolic link"""
#     166 try:
# --> 167     st = os.lstat(path)
#     168 except (OSError, ValueError, AttributeError):
#     169     return False
#
# File /usr/local/lib/python3.8/site-packages/ray/_private/worker.py:1640, in sigterm_handler(signum, frame)
#    1639 def sigterm_handler(signum, frame):
# -> 1640     sys.exit(signum)
#
# SystemExit: 15
# <h4>Bob's Output:</h4>
# 2023-10-10 05:18:26,340	WARNING worker.py:1851 -- Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 823, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 875, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 830, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 834, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 780, in ray._raylet.execute_task.function_executor
#   File "/usr/local/lib/python3.8/site-packages/ray/_private/function_manager.py", line 674, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "/usr/local/lib/python3.8/site-packages/secretflow/device/device/spu.py", line 370, in __init__
#     self.link = spu_link.create_brpc(desc, rank)
# RuntimeError: what:
# 	[external/yacl/yacl/link/transport/brpc_link.cc:130] brpc server failed start
# Stacktrace:
# #0 yacl::link::FactoryBrpc::CreateContext()+0x7f4337ac5799
# #1 pybind11::cpp_function::initialize<>()::{lambda()#3}::_FUN()+0x7f43365ecad6
# #2 pybind11::cpp_function::dispatcher()+0x7f43365cf1c6
# #3 PyCFunction_Call+0x4e0212
#
# stacktrace:
# #0 yacl::link::FactoryBrpc::CreateContext()+0x7f4337ac5799
# #1 pybind11::cpp_function::initialize<>()::{lambda()#3}::_FUN()+0x7f43365ecad6
# #2 pybind11::cpp_function::dispatcher()+0x7f43365cf1c6
# #3 PyCFunction_Call+0x4e0212
#
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 1135, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 1045, in ray._raylet.execute_task_with_cancellation_handler
#   File "python/ray/_raylet.pyx", line 782, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 945, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 575, in ray._raylet.store_task_errors
#   File "/usr/local/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "/usr/local/lib/python3.8/site-packages/secretflow/device/device/spu.py", line 379, in __repr__
#     return f"SPURuntime(device_id={self.id}, party={self.party})"
# AttributeError: 'SPURuntime' object has no attribute 'id'
# An unexpected internal error occurred while the worker was executing a task.
# 2023-10-10 05:18:26,344	WARNING worker.py:1851 -- A worker died or was killed while executing a task by an unexpected system error. To troubleshoot the problem, check the logs for the dead worker. RayTask ID: ffffffffffffffff4c27e5a576a7f5ed4cf278bf02000000 Worker ID: 065d0e7208e49ea2692c8b825e2d496a309475a1d64b8c3c7bfaae98 Node ID: 8871018bd030fde1635d48819bd875eab214910b48928400116b43b3 Worker IP address: 172.21.0.3 Worker port: 10009 Worker PID: 683 Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code None.
#  Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 823, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 875, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 830, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 834, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 780, in ray._raylet.execute_task.function_executor
#   File "/usr/local/lib/python3.8/site-packages/ray/_private/function_manager.py", line 674, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "/usr/local/lib/python3.8/site-packages/secretflow/device/device/spu.py", line 370, in __init__
#     self.link = spu_link.create_brpc(desc, rank)
# RuntimeError: what:
# 	[external/yacl/yacl/link/transport/brpc_link.cc:130] brpc server failed start
# Stacktrace:
# #0 yacl::link::FactoryBrpc::CreateContext()+0x7f4337ac5799
# #1 pybind11::cpp_function::initialize<>()::{lambda()#3}::_FUN()+0x7f43365ecad6
# #2 pybind11::cpp_function::dispatcher()+0x7f43365cf1c6
# #3 PyCFunction_Call+0x4e0212
#
# stacktrace:
# #0 yacl::link::FactoryBrpc::CreateContext()+0x7f4337ac5799
# #1 pybind11::cpp_function::initialize<>()::{lambda()#3}::_FUN()+0x7f43365ecad6
# #2 pybind11::cpp_function::dispatcher()+0x7f43365cf1c6
# #3 PyCFunction_Call+0x4e0212
#
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 1135, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 1045, in ray._raylet.execute_task_with_cancellation_handler
#   File "python/ray/_raylet.pyx", line 782, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 945, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 575, in ray._raylet.store_task_errors
#   File "/usr/local/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "/usr/local/lib/python3.8/site-packages/secretflow/device/device/spu.py", line 379, in __repr__
#     return f"SPURuntime(device_id={self.id}, party={self.party})"
# AttributeError: 'SPURuntime' object has no attribute 'id'
# An unexpected internal error occurred while the worker was executing a task.
# 2023-10-10 05:18:26 WARNING cleanup.py:99 [bob] --  Failed to send ObjectRef(0021899358e75e3c9befabcd882e585b40b020b40200000001000000) with error: ray::SenderProxyActor.send() (pid=640, ip=172.21.0.3, repr=<fed.proxy.barriers.SenderProxyActor object at 0x7f77c408e310>)
#   At least one of the input arguments for this task could not be computed:
# ray.exceptions.RayActorError: The actor died unexpectedly before finishing this task.
# 	class_name: SPURuntime
# 	actor_id: 4c27e5a576a7f5ed4cf278bf02000000
# 	pid: 683
# 	namespace: 7210a617-9c9a-4fff-a098-39cd64f2eb10
# 	ip: 172.21.0.3
# The actor is dead because its worker process has died. Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code None.
#  Traceback (most recent call last):
#   File "/usr/local/lib/python3.8/site-packages/secretflow/device/device/spu.py", line 370, in __init__
#     self.link = spu_link.create_brpc(desc, rank)
# RuntimeError: what:
# 	[external/yacl/yacl/link/transport/brpc_link.cc:130] brpc server failed start
# Stacktrace:
# #0 yacl::link::FactoryBrpc::CreateContext()+0x7f4337ac5799
# #1 pybind11::cpp_function::initialize<>()::{lambda()#3}::_FUN()+0x7f43365ecad6
# #2 pybind11::cpp_function::dispatcher()+0x7f43365cf1c6
# #3 PyCFunction_Call+0x4e0212
#
# stacktrace:
# #0 yacl::link::FactoryBrpc::CreateContext()+0x7f4337ac5799
# #1 pybind11::cpp_function::initialize<>()::{lambda()#3}::_FUN()+0x7f43365ecad6
# #2 pybind11::cpp_function::dispatcher()+0x7f43365cf1c6
# #3 PyCFunction_Call+0x4e0212
#
#
#
# During handling of the above exception, another exception occurred:
#
# ray::SenderProxyActor.send() (pid=640, ip=172.21.0.3, repr=<fed.proxy.barriers.SenderProxyActor object at 0x7f77c408e310>)
#   File "/usr/local/lib/python3.8/site-packages/secretflow/device/device/spu.py", line 379, in __repr__
#     return f"SPURuntime(device_id={self.id}, party={self.party})"
# AttributeError: 'SPURuntime' object has no attribute 'id'
# An unexpected internal error occurred while the worker was executing a task.
# 2023-10-10 05:18:26 WARNING cleanup.py:102 [bob] --  Signal self to exit.
# 2023-10-10 05:18:26 INFO cleanup.py:106 [bob] --  Check sending thread was exited.
# *** SIGTERM received at time=1696915106 on cpu 0 ***
# PC: @     0x7f663c61182d  (unknown)  __lll_lock_wait
#     @     0x7f663c612cf0  (unknown)  (unknown)
# [2023-10-10 05:18:26,355 E 527 527] logging.cc:361: *** SIGTERM received at time=1696915106 on cpu 0 ***
# [2023-10-10 05:18:26,355 E 527 527] logging.cc:361: PC: @     0x7f663c61182d  (unknown)  __lll_lock_wait
# [2023-10-10 05:18:26,355 E 527 527] logging.cc:361:     @     0x7f663c612cf0  (unknown)  (unknown)
# (SPURuntime pid=683) 2023-10-10 05:18:26,338	ERROR worker.py:763 -- Worker exits with an exit code None.
# (SPURuntime pid=683)  Traceback (most recent call last):
# (SPURuntime pid=683)   File "python/ray/_raylet.pyx", line 823, in ray._raylet.execute_task
# (SPURuntime pid=683)   File "python/ray/_raylet.pyx", line 875, in ray._raylet.execute_task
# (SPURuntime pid=683)   File "python/ray/_raylet.pyx", line 830, in ray._raylet.execute_task
# (SPURuntime pid=683)   File "python/ray/_raylet.pyx", line 834, in ray._raylet.execute_task
# (SPURuntime pid=683)   File "python/ray/_raylet.pyx", line 780, in ray._raylet.execute_task.function_executor
# (SPURuntime pid=683)   File "/usr/local/lib/python3.8/site-packages/ray/_private/function_manager.py", line 674, in actor_method_executor
# (SPURuntime pid=683)     return method(__ray_actor, *args, **kwargs)
# (SPURuntime pid=683)   File "/usr/local/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (SPURuntime pid=683)     return method(self, *_args, **_kwargs)
# (SPURuntime pid=683)   File "/usr/local/lib/python3.8/site-packages/secretflow/device/device/spu.py", line 370, in __init__
# (SPURuntime pid=683)     self.link = spu_link.create_brpc(desc, rank)
# (SPURuntime pid=683) RuntimeError: what:
# (SPURuntime pid=683) 	[external/yacl/yacl/link/transport/brpc_link.cc:130] brpc server failed start
# (SPURuntime pid=683) Stacktrace:
# (SPURuntime pid=683) #0 yacl::link::FactoryBrpc::CreateContext()+0x7f4337ac5799
# (SPURuntime pid=683) #1 pybind11::cpp_function::initialize<>()::{lambda()#3}::_FUN()+0x7f43365ecad6
# (SPURuntime pid=683) #2 pybind11::cpp_function::dispatcher()+0x7f43365cf1c6
# (SPURuntime pid=683) #3 PyCFunction_Call+0x4e0212
# (SPURuntime pid=683)
# (SPURuntime pid=683) stacktrace:
# (SPURuntime pid=683) #0 yacl::link::FactoryBrpc::CreateContext()+0x7f4337ac5799
# (SPURuntime pid=683) #1 pybind11::cpp_function::initialize<>()::{lambda()#3}::_FUN()+0x7f43365ecad6
# (SPURuntime pid=683) #2 pybind11::cpp_function::dispatcher()+0x7f43365cf1c6
# (SPURuntime pid=683) #3 PyCFunction_Call+0x4e0212
# (SPURuntime pid=683)
# (SPURuntime pid=683)
# (SPURuntime pid=683)
# (SPURuntime pid=683) During handling of the above exception, another exception occurred:
# (SPURuntime pid=683)
# (SPURuntime pid=683) Traceback (most recent call last):
# (SPURuntime pid=683)   File "python/ray/_raylet.pyx", line 1135, in ray._raylet.task_execution_handler
# (SPURuntime pid=683)   File "python/ray/_raylet.pyx", line 1045, in ray._raylet.execute_task_with_cancellation_handler
# (SPURuntime pid=683)   File "python/ray/_raylet.pyx", line 782, in ray._raylet.execute_task
# (SPURuntime pid=683)   File "python/ray/_raylet.pyx", line 945, in ray._raylet.execute_task
# (SPURuntime pid=683)   File "python/ray/_raylet.pyx", line 575, in ray._raylet.store_task_errors
# (SPURuntime pid=683)   File "/usr/local/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (SPURuntime pid=683)     return method(self, *_args, **_kwargs)
# (SPURuntime pid=683)   File "/usr/local/lib/python3.8/site-packages/secretflow/device/device/spu.py", line 379, in __repr__
# (SPURuntime pid=683)     return f"SPURuntime(device_id={self.id}, party={self.party})"
# (SPURuntime pid=683) AttributeError: 'SPURuntime' object has no attribute 'id'
# (SPURuntime pid=683) An unexpected internal error occurred while the worker was executing a task.
# (SPURuntime pid=683) Traceback (most recent call last):
# (SPURuntime pid=683)   File "python/ray/_raylet.pyx", line 823, in ray._raylet.execute_task
# (SPURuntime pid=683)   File "python/ray/_raylet.pyx", line 875, in ray._raylet.execute_task
# (SPURuntime pid=683)   File "python/ray/_raylet.pyx", line 830, in ray._raylet.execute_task
# (SPURuntime pid=683)   File "python/ray/_raylet.pyx", line 834, in ray._raylet.execute_task
# (SPURuntime pid=683)   File "python/ray/_raylet.pyx", line 780, in ray._raylet.execute_task.function_executor
# (SPURuntime pid=683)   File "/usr/local/lib/python3.8/site-packages/ray/_private/function_manager.py", line 674, in actor_method_executor
# (SPURuntime pid=683)     return method(__ray_actor, *args, **kwargs)
# (SPURuntime pid=683)   File "/usr/local/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (SPURuntime pid=683)     return method(self, *_args, **_kwargs)
# (SPURuntime pid=683)   File "/usr/local/lib/python3.8/site-packages/secretflow/device/device/spu.py", line 370, in __init__
# (SPURuntime pid=683)     self.link = spu_link.create_brpc(desc, rank)
# (SPURuntime pid=683) RuntimeError: what:
# (SPURuntime pid=683) 	[external/yacl/yacl/link/transport/brpc_link.cc:130] brpc server failed start
# (SPURuntime pid=683) Stacktrace:
# (SPURuntime pid=683) #0 yacl::link::FactoryBrpc::CreateContext()+0x7f4337ac5799
# (SPURuntime pid=683) #1 pybind11::cpp_function::initialize<>()::{lambda()#3}::_FUN()+0x7f43365ecad6
# (SPURuntime pid=683) #2 pybind11::cpp_function::dispatcher()+0x7f43365cf1c6
# (SPURuntime pid=683) #3 PyCFunction_Call+0x4e0212
# (SPURuntime pid=683)
# (SPURuntime pid=683) stacktrace:
# (SPURuntime pid=683) #0 yacl::link::FactoryBrpc::CreateContext()+0x7f4337ac5799
# (SPURuntime pid=683) #1 pybind11::cpp_function::initialize<>()::{lambda()#3}::_FUN()+0x7f43365ecad6
# (SPURuntime pid=683) #2 pybind11::cpp_function::dispatcher()+0x7f43365cf1c6
# (SPURuntime pid=683) #3 PyCFunction_Call+0x4e0212
# (SPURuntime pid=683)
# (SPURuntime pid=683)
# (SPURuntime pid=683)
# (SPURuntime pid=683) During handling of the above exception, another exception occurred:
# (SPURuntime pid=683)
# (SPURuntime pid=683) Traceback (most recent call last):
# (SPURuntime pid=683)   File "python/ray/_raylet.pyx", line 1135, in ray._raylet.task_execution_handler
# (SPURuntime pid=683)   File "python/ray/_raylet.pyx", line 1045, in ray._raylet.execute_task_with_cancellation_handler
# (SPURuntime pid=683)   File "python/ray/_raylet.pyx", line 782, in ray._raylet.execute_task
# (SPURuntime pid=683)   File "python/ray/_raylet.pyx", line 945, in ray._raylet.execute_task
# (SPURuntime pid=683)   File "python/ray/_raylet.pyx", line 575, in ray._raylet.store_task_errors
# (SPURuntime pid=683)   File "/usr/local/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
# (SPURuntime pid=683)     return method(self, *_args, **_kwargs)
# (SPURuntime pid=683)   File "/usr/local/lib/python3.8/site-packages/secretflow/device/device/spu.py", line 379, in __repr__
# (SPURuntime pid=683)     return f"SPURuntime(device_id={self.id}, party={self.party})"
# (SPURuntime pid=683) AttributeError: 'SPURuntime' object has no attribute 'id'
# (SPURuntime pid=683)
# (SPURuntime pid=683) During handling of the above exception, another exception occurred:
# (SPURuntime pid=683)
# (SPURuntime pid=683) Traceback (most recent call last):
# (SPURuntime pid=683)   File "python/ray/_raylet.pyx", line 1176, in ray._raylet.task_execution_handler
# (SPURuntime pid=683) SystemExit
# (SPURuntime pid=683) 2023-10-10 05:18:26.321 [error] [server.cpp:BRPC:1023] Fail to listen 172.21.0.2:8081
# (SPURuntime pid=683) 2023-10-10 05:18:26.337 [warning] [channel.h:~Channel:151] Channel destructor is called before WaitLinkTaskFinish, try stop send thread
# ---------------------------------------------------------------------------
# RayActorError                             Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[4], line 7
#       6 output_path = {alice: f'{current_dir}/iris_alice_psi.csv', bob: f'{current_dir}/iris_alice_psi.csv'}
# ----> 7 spu.psi_csv('uid', input_path, output_path, 'alice')
#
# File /usr/local/lib/python3.8/site-packages/secretflow/device/device/spu.py:1978, in SPU.psi_csv(self, key, input_path, output_path, receiver, protocol, precheck_input, sort, broadcast_result, bucket_size, curve_type, preprocess_path, ecdh_secret_key_path, dppsi_bob_sub_sampling, dppsi_epsilon, progress_callbacks, callbacks_interval_ms)
#    1948 """Private set intersection with csv file.
#    1949
#    1950 Args:
#    (...)
#    1975     List[Dict]: PSI reports output by SPU with order reserved.
#    1976 """
# -> 1978 return dispatch(
#    1979     'psi_csv',
#    1980     self,
#    1981     key,
#    1982     input_path,
#    1983     output_path,
#    1984     receiver,
#    1985     protocol,
#    1986     precheck_input,
#    1987     sort,
#    1988     broadcast_result,
#    1989     bucket_size,
#    1990     curve_type,
#    1991     preprocess_path,
#    1992     ecdh_secret_key_path,
#    1993     dppsi_bob_sub_sampling,
#    1994     dppsi_epsilon,
#    1995     progress_callbacks,
#    1996     callbacks_interval_ms,
#    1997 )
#
# File /usr/local/lib/python3.8/site-packages/secretflow/device/device/register.py:111, in dispatch(name, self, *args, **kwargs)
#     102 """Dispatch device kernel.
#     103
#     104 Args:
#    (...)
#     109     Kernel execution result.
#     110 """
# --> 111 return _registrar.dispatch(self.device_type, name, self, *args, **kwargs)
#
# File /usr/local/lib/python3.8/site-packages/secretflow/device/device/register.py:80, in Registrar.dispatch(self, device_type, name, *args, **kwargs)
#      79     raise KeyError(f'device: {device_type}, op: {name} not registered')
# ---> 80 return self._ops[device_type][name](*args, **kwargs)
#
# File /usr/local/lib/python3.8/site-packages/secretflow/device/kernels/spu.py:318, in psi_csv(device, key, input_path, output_path, receiver, protocol, precheck_input, sort, broadcast_result, bucket_size, curve_type, preprocess_path, ecdh_secret_key_path, dppsi_bob_sub_sampling, dppsi_epsilon, progress_callbacks, callbacks_interval_ms)
#     317 # wait for all tasks done
# --> 318 return sfd.get(res)
#
# File /usr/local/lib/python3.8/site-packages/secretflow/distributed/primitive.py:73, in get(object_refs)
#      72 if production_mode():
# ---> 73     return fed.get(object_refs)
#      74 else:
#
# File /usr/local/lib/python3.8/site-packages/fed/api.py:395, in get(fed_objects)
#     393         ray_refs.append(received_ray_object_ref)
# --> 395 values = ray.get(ray_refs)
#     396 if is_individual_id:
#
# File /usr/local/lib/python3.8/site-packages/ray/_private/client_mode_hook.py:105, in client_mode_hook.<locals>.wrapper(*args, **kwargs)
#     104         return getattr(ray, func.__name__)(*args, **kwargs)
# --> 105 return func(*args, **kwargs)
#
# File /usr/local/lib/python3.8/site-packages/ray/_private/worker.py:2311, in get(object_refs, timeout)
#    2310         else:
# -> 2311             raise value
#    2313 if is_individual_id:
#
# RayActorError: The actor died unexpectedly before finishing this task.
# 	class_name: SPURuntime
# 	actor_id: 4c27e5a576a7f5ed4cf278bf02000000
# 	pid: 683
# 	namespace: 7210a617-9c9a-4fff-a098-39cd64f2eb10
# 	ip: 172.21.0.3
# The actor is dead because its worker process has died. Worker exit type: SYSTEM_ERROR Worker exit detail: Worker exits unexpectedly. Worker exits with an exit code None.
#  Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 823, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 875, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 830, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 834, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 780, in ray._raylet.execute_task.function_executor
#   File "/usr/local/lib/python3.8/site-packages/ray/_private/function_manager.py", line 674, in actor_method_executor
#     return method(__ray_actor, *args, **kwargs)
#   File "/usr/local/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "/usr/local/lib/python3.8/site-packages/secretflow/device/device/spu.py", line 370, in __init__
#     self.link = spu_link.create_brpc(desc, rank)
# RuntimeError: what:
# 	[external/yacl/yacl/link/transport/brpc_link.cc:130] brpc server failed start
# Stacktrace:
# #0 yacl::link::FactoryBrpc::CreateContext()+0x7f4337ac5799
# #1 pybind11::cpp_function::initialize<>()::{lambda()#3}::_FUN()+0x7f43365ecad6
# #2 pybind11::cpp_function::dispatcher()+0x7f43365cf1c6
# #3 PyCFunction_Call+0x4e0212
#
# stacktrace:
# #0 yacl::link::FactoryBrpc::CreateContext()+0x7f4337ac5799
# #1 pybind11::cpp_function::initialize<>()::{lambda()#3}::_FUN()+0x7f43365ecad6
# #2 pybind11::cpp_function::dispatcher()+0x7f43365cf1c6
# #3 PyCFunction_Call+0x4e0212
#
#
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "python/ray/_raylet.pyx", line 1135, in ray._raylet.task_execution_handler
#   File "python/ray/_raylet.pyx", line 1045, in ray._raylet.execute_task_with_cancellation_handler
#   File "python/ray/_raylet.pyx", line 782, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 945, in ray._raylet.execute_task
#   File "python/ray/_raylet.pyx", line 575, in ray._raylet.store_task_errors
#   File "/usr/local/lib/python3.8/site-packages/ray/util/tracing/tracing_helper.py", line 466, in _resume_span
#     return method(self, *_args, **_kwargs)
#   File "/usr/local/lib/python3.8/site-packages/secretflow/device/device/spu.py", line 379, in __repr__
#     return f"SPURuntime(device_id={self.id}, party={self.party})"
# AttributeError: 'SPURuntime' object has no attribute 'id'
# An unexpected internal error occurred while the worker was executing a task.
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File /usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:2105, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2103         stb = value._render_traceback_()
#    2104     else:
# -> 2105         stb = self.InteractiveTB.structured_traceback(
#    2106             etype, value, tb, tb_offset=tb_offset
#    2107         )
#    2109 except Exception:
#    2110     print(
#    2111         "Unexpected exception formatting exception. Falling back to standard exception"
#    2112     )
#
# File /usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py:1396, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1394 else:
#    1395     self.tb = etb
# -> 1396 return FormattedTB.structured_traceback(
#    1397     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1398 )
#
# File /usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py:1287, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1284 mode = self.mode
#    1285 if mode in self.verbose_modes:
#    1286     # Verbose modes need a full traceback
# -> 1287     return VerboseTB.structured_traceback(
#    1288         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1289     )
#    1290 elif mode == 'Minimal':
#    1291     return ListTB.get_exception_only(self, etype, value)
#
# File /usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py:1140, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1131 def structured_traceback(
#    1132     self,
#    1133     etype: type,
#    (...)
#    1137     number_of_lines_of_context: int = 5,
#    1138 ):
#    1139     """Return a nice text document describing the traceback."""
# -> 1140     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1141                                                            tb_offset)
#    1143     colors = self.Colors  # just a shorthand + quicker name lookup
#    1144     colorsnormal = colors.Normal  # used a lot
#
# File /usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py:1030, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1027 assert isinstance(tb_offset, int)
#    1028 head = self.prepare_header(str(etype), self.long_header)
#    1029 records = (
# -> 1030     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1031 )
#    1033 frames = []
#    1034 skipped = 0
#
# File /usr/local/lib/python3.8/site-packages/IPython/core/ultratb.py:1081, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1079 before = context - after
#    1080 if self.has_colors:
# -> 1081     style = get_style_by_name("default")
#    1082     style = stack_data.style_with_executing_node(style, self._tb_highlight)
#    1083     formatter = Terminal256Formatter(style=style)
#
# File /usr/local/lib/python3.8/site-packages/pygments/styles/__init__.py:90, in get_style_by_name(name)
#      87     cls = name.title() + "Style"
#      89 try:
# ---> 90     mod = __import__('pygments.styles.' + mod, None, None, [cls])
#      91 except ImportError:
#      92     raise ClassNotFound("Could not find style module %r" % mod +
#      93                      (builtin and ", though it should be builtin") + ".")
#
# File <frozen importlib._bootstrap>:991, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:975, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:671, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:839, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:934, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1032, in get_data(self, path)
#
# File /usr/local/lib/python3.8/site-packages/ray/_private/worker.py:1640, in sigterm_handler(signum, frame)
#    1639 def sigterm_handler(signum, frame):
# -> 1640     sys.exit(signum)
#
# SystemExit: 15
